# %%
import urllib, requests, socket, re, lxml, io, bs4, sqlite3, pandas, sqlalchemy
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from requests.compat import urljoin, quote_plus, urlparse, unquote
url='https://agroserver.ru/search/%D0%BC%D1%8F%D1%82%D0%B0/1/0/0/0/0/1/'
proxies = {
    "http": "http://8.211.129.117",
    "https": "http://8.211.129.117",
}

try:
    response = requests.get(url, proxies=proxies, timeout=(5, 30))
    print(response.text)
except requests.RequestException as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: HTTPSConnectionPool(host='agroserver.ru', port=443): Max retries exceeded with url: /search/%D0%BC%D1%8F%D1%82%D0%B0/1/0/0/0/0/1/ (Caused by ProxyError('Unable to connect to proxy', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7a5d93b595d0>: Failed to establish a new connection: [Errno 111] Connection refused')))

# %% [markdown]
# Парсинг с Википедии (получаю координаты)
# На вход есть лист из названий городов

# %%
import urllib, requests, socket, re, lxml, io, bs4, sqlite3, pandas, sqlalchemy
from bs4 import BeautifulSoup
from urllib.parse import urljoin
from requests.compat import urljoin, quote_plus, urlparse, unquote
import pandas as pd

def get_lat(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        map_links = soup.find_all('a', class_='mw-kartographer-maplink')
        if map_links:
            map_link = map_links[0]
            lat = float(map_link['data-lat'])
            return lat
        return None, None
    except:
        return None, None
def get_lon(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.text, 'html.parser')
        map_links = soup.find_all('a', class_='mw-kartographer-maplink')
        if map_links:
            map_link = map_links[0]
            lon = float(map_link['data-lon'])
            return lon
        return None, None
    except:
        return None, None
lat=[]
lon=[]
places = ['Москва', 'Москва', 'Славянск-на-Кубани', 'Ростов-на-Дону', 'Симферополь', 'Симферополь', 'Херсон', 'Симферополь', 'Дрожжановски', 'Павловски', 'Павловски', 'Сакски', 'Нытва', 'Челябинск', 'Воркута', 'Иссык-Кульска', 'Анапа', 'Украин', 'Екатеринбург', 'Казань', 'Ереван', 'Москва', 'Ярославль', 'Краснодарски', 'Москва', 'Екатеринбург', 'Пермь', 'Самара', 'Оренбург', 'Уфа', 'Москва', 'Смоленска', 'Ростов-на-Дону', 'Павловски', 'Павловски', 'Симферопольски', 'Павловски', 'Волгоградска', 'Тюмень', 'Челябинска', 'Томск', 'Павлодарска', 'Москва', 'Москва', 'Санкт-Петербург', 'Москва', 'Санкт-Петербург', 'Симферополь', 'Москва']

cities=['Киров', 'Астрахань', 'Саратов']
for i in cities:
  url='https://ru.wikipedia.org/wiki/'+i
  lat.append(get_lat(url))
  lon.append(get_lon(url))

d = {'город': cities, 'долгота': lon, 'широта': lat}
df1 = pd.DataFrame(data=d)
df1
# Out:
#        город   долгота    широта
# 0      Киров  49.65000  58.60000
# 1  Астрахань  48.03333  46.33333
# 2    Саратов  46.00000  51.53333

# %% [markdown]
# Собираем датафреймы для каждого вида чая

# %% [markdown]
# Я собрала данные и соединила их в pycharm. Но так как графики хочу строить тут, то с помощью DeepSeek, копирую сюда мой датафрейм.
# Промт: "сделай это кодом в python"

# %%
import pandas as pd
data_mint = {
    'Город': [
        'Москва', 'Москва', 'Москва', 'Москва', 'Москва', 'Москва', 'Москва', 'Москва',
        'Славянск-на-Кубани', 'Ростов-на-Дону', 'Ростов-на-Дону', 'Херсон', 'Симферополь', 'Симферополь',
        'Нытва', 'Анапа', 'Екатеринбург', 'Екатеринбург', 'Казань', 'Ереван', 'Ярославль', 'Пермь',
        'Самара', 'Оренбург', 'Уфа', 'Тюмень', 'Томск', 'Санкт-Петербург', 'Санкт-Петербург'
    ],
    'долгота': [
        37.6175, 37.6175, 37.6175, 37.6175, 37.6175, 37.6175, 37.6175, 37.6175,
        38.12472, 39.71056, 39.71056, 32.625, 34.10417, 34.10417,
        55.33333, 37.317481, 60.58333, 60.58333, 49.11444, 44.51667, 39.85,
        56.24889, 50.11667, 55.1, 55.96667, 65.53333, 84.95222, 30.31667, 30.31667
    ],
    'широта': [
        55.750556, 55.750556, 55.750556, 55.750556, 55.750556, 55.750556, 55.750556, 55.750556,
        45.25861, 47.24056, 47.24056, 46.6425, 44.94806, 44.94806,
        57.93333, 44.893857, 56.83333, 56.83333, 55.79083, 40.18333, 57.61667,
        58.01389, 53.18333, 51.76667, 54.73333, 57.15, 56.48861, 59.95, 59.95
    ],
    'растение': [
        'мята', 'мята', 'мята', 'мята', 'мята', 'мята', 'мята', 'мята',
        'мята', 'мята', 'мята', 'мята', 'мята', 'мята',
        'мята', 'мята', 'мята', 'мята', 'мята', 'мята', 'мята',
        'мята', 'мята', 'мята', 'мята', 'мята', 'мята', 'мята', 'мята'
    ],
    'цена': [
        490, 320, 290, 400, 670, 350, 450, 350,
        350, 250, 800, 150, 400, 300,
        350, 250, 680, 300, 700, 200, 350,
        300, 300, 300, 300, 100, 300, 420, 840
    ]
}


df_mint = pd.DataFrame(data_mint)


df_mint
# Out:
#                  Город    долгота     широта растение  цена
# 0               Москва  37.617500  55.750556     мята   490
# 1               Москва  37.617500  55.750556     мята   320
# 2               Москва  37.617500  55.750556     мята   290
# 3               Москва  37.617500  55.750556     мята   400
# 4               Москва  37.617500  55.750556     мята   670
# 5               Москва  37.617500  55.750556     мята   350
# 6               Москва  37.617500  55.750556     мята   450
# 7               Москва  37.617500  55.750556     мята   350
# 8   Славянск-на-Кубани  38.124720  45.258610     мята   350
# 9       Ростов-на-Дону  39.710560  47.240560     мята   250
# 10      Ростов-на-Дону  39.710560  47.240560     мята   800
# 11              Херсон  32.625000  46.642500     мята   150
# 12         Симферополь  34.104170  44.948060     мята   400
# 13         Симферополь  34.104170  44.948060     мята   300
# 14               Нытва  55.333330  57.933330     мята   350
# 15               Анапа  37.317481  44.893857     мята   250
# 16        Екатеринбург  60.583330  56.833330     мята   680
# 17        Екатеринбург  60.583330  56.833330     мята   300
# 18              Казань  49.114440  55.790830     мята   700
# 19              Ереван  44.516670  40.183330     мята   200
# 20           Ярославль  39.850000  57.616670     мята   350
# 21               Пермь  56.248890  58.013890     мята   300
# 22              Самара  50.116670  53.183330     мята   300
# 23            Оренбург  55.100000  51.766670     мята   300
# 24                 Уфа  55.966670  54.733330     мята   300
# 25              Тюмень  65.533330  57.150000     мята   100
# 26               Томск  84.952220  56.488610     мята   300
# 27     Санкт-Петербург  30.316670  59.950000     мята   420
# 28     Санкт-Петербург  30.316670  59.950000     мята   840

# %% [markdown]
# Рисуем Dashboard

# %% [markdown]
# Я делаю то же самое для иван-чая (так же код в pycharm и тот же промт)

# %%
data_ivan = {
    'город': [
        'Нижнеудинск', 'Иркутск', 'Вологда', 'Вологда', 'Вологда', 'Санкт-Петербург',
        'Череповец', 'Киров', 'Верхотурье', 'Москва', 'Москва', 'Москва', 'Чусовой'
    ],
    'долгота': [
        99.01667, 104.3, 39.9, 39.9, 39.9, 30.31667,
        37.9, 49.65, 60.8, 37.6175, 37.6175, 37.6175, 57.81667
    ],
    'широта': [
        54.9, 52.28333, 59.216667, 59.216667, 59.216667, 59.95,
        59.11667, 58.6, 58.86667, 55.750556, 55.750556, 55.750556, 58.28333
    ],
    'растение': [
        'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай',
        'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай', 'иван-чай'
    ],
    'цена': [
        250, 600, 750, 400, 800, 800,
        650, 600, 850, 450, 650, 580, 250
    ]
}


df_ivan = pd.DataFrame(data_ivan)


df_ivan
# Out:
#               город    долгота     широта  растение  цена
# 0       Нижнеудинск   99.01667  54.900000  иван-чай   250
# 1           Иркутск  104.30000  52.283330  иван-чай   600
# 2           Вологда   39.90000  59.216667  иван-чай   750
# 3           Вологда   39.90000  59.216667  иван-чай   400
# 4           Вологда   39.90000  59.216667  иван-чай   800
# 5   Санкт-Петербург   30.31667  59.950000  иван-чай   800
# 6         Череповец   37.90000  59.116670  иван-чай   650
# 7             Киров   49.65000  58.600000  иван-чай   600
# 8        Верхотурье   60.80000  58.866670  иван-чай   850
# 9            Москва   37.61750  55.750556  иван-чай   450
# 10           Москва   37.61750  55.750556  иван-чай   650
# 11           Москва   37.61750  55.750556  иван-чай   580
# 12          Чусовой   57.81667  58.283330  иван-чай   250

# %% [markdown]
# Последний подопытный- мелисса

# %%
import pandas as pd

data_melissa = {
    "город": ["Санкт-Петербург", "Санкт-Петербург", "Москва", "Барнаул"],
    "долгота": [30.31667, 30.31667, 37.6175, 83.77833],
    "широта": [59.95, 59.95, 55.750556, 53.347361],
    "растение": ["мелисса", "мелисса", "мелисса", "мелисса"],
    "цена": [850, 100, 805, 160]
}


df_melissa = pd.DataFrame(data_melissa)

df_melissa
# Out:
#              город   долгота     широта растение  цена
# 0  Санкт-Петербург  30.31667  59.950000  мелисса   850
# 1  Санкт-Петербург  30.31667  59.950000  мелисса   100
# 2           Москва  37.61750  55.750556  мелисса   805
# 3          Барнаул  83.77833  53.347361  мелисса   160

# %% [markdown]
# Теперь я рисую карту, чтобы провести глубокий эмпирический анализ

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
df_mint['обратная_цена'] = 1 / df_mint['цена']
df_ivan['обратная_цена'] = 1 / df_ivan['цена']
df_melissa['обратная_цена'] = 1 / df_melissa['цена']

fig1 = px.scatter_geo(df_mint, lat='широта', lon='долгота', hover_name='Город', title='Мята',
                        color='обратная_цена', size='обратная_цена',
                        projection='equirectangular', symbol_sequence=['star'], color_continuous_scale='RdYlGn', text='Город', width=1200,
                     height=700, opacity=0.8)
fig2 = px.scatter_geo(df_ivan, lat='широта', lon='долгота', hover_name='город',
                        color='обратная_цена', size='обратная_цена',
                        projection='equirectangular', title='Иван чай', symbol_sequence=['circle'],  color_continuous_scale='RdYlGn', text='город', width=1200,
                     height=700, opacity=0.8)
fig3 = px.scatter_geo(df_melissa, lat='широта', lon='долгота', hover_name='город',
                        color='обратная_цена', size='обратная_цена',
                        projection='equirectangular', title='Мелисса', symbol_sequence=['cross'],  color_continuous_scale='RdYlGn', text='город', width=1200,
                     height=700, opacity=0.8)
fig1.show()
fig2.show()
fig3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bb5e26d5-38a2-4a23-9a38-198ab8969b15" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bb5e26d5-38a2-4a23-9a38-198ab8969b15")) {                    Plotly.newPlot(                        "bb5e26d5-38a2-4a23-9a38-198ab8969b15",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eобратная_цена=%{marker.color}\u003cbr\u003eГород=%{text}\u003cbr\u003eширота=%{lat}\u003cbr\u003eдолгота=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Москва","Москва","Москва","Москва","Москва","Москва","Москва","Москва","Славянск-на-Кубани","Ростов-на-Дону","Ростов-на-Дону","Херсон","Симферополь","Симферополь","Нытва","Анапа","Екатеринбург","Екатеринбург","Казань","Ереван","Ярославль","Пермь","Самара","Оренбург","Уфа","Тюмень","Томск","Санкт-Петербург","Санкт-Петербург"],"lat":[55.750556,55.750556,55.750556,55.750556,55.750556,55.750556,55.750556,55.750556,45.25861,47.24056,47.24056,46.6425,44.94806,44.94806,57.93333,44.893857,56.83333,56.83333,55.79083,40.18333,57.61667,58.01389,53.18333,51.76667,54.73333,57.15,56.48861,59.95,59.95],"legendgroup":"","lon":[37.6175,37.6175,37.6175,37.6175,37.6175,37.6175,37.6175,37.6175,38.12472,39.71056,39.71056,32.625,34.10417,34.10417,55.33333,37.317481,60.58333,60.58333,49.11444,44.51667,39.85,56.24889,50.11667,55.1,55.96667,65.53333,84.95222,30.31667,30.31667],"marker":{"color":[0.0020408163265306124,0.003125,0.0034482758620689655,0.0025,0.0014925373134328358,0.002857142857142857,0.0022222222222222222,0.002857142857142857,0.002857142857142857,0.004,0.00125,0.006666666666666667,0.0025,0.0033333333333333335,0.002857142857142857,0.004,0.0014705882352941176,0.0033333333333333335,0.0014285714285714286,0.005,0.002857142857142857,0.0033333333333333335,0.0033333333333333335,0.0033333333333333335,0.0033333333333333335,0.01,0.0033333333333333335,0.002380952380952381,0.0011904761904761906],"coloraxis":"coloraxis","opacity":0.8,"size":[0.0020408163265306124,0.003125,0.0034482758620689655,0.0025,0.0014925373134328358,0.002857142857142857,0.0022222222222222222,0.002857142857142857,0.002857142857142857,0.004,0.00125,0.006666666666666667,0.0025,0.0033333333333333335,0.002857142857142857,0.004,0.0014705882352941176,0.0033333333333333335,0.0014285714285714286,0.005,0.002857142857142857,0.0033333333333333335,0.0033333333333333335,0.0033333333333333335,0.0033333333333333335,0.01,0.0033333333333333335,0.002380952380952381,0.0011904761904761906],"sizemode":"area","sizeref":0.000025,"symbol":"star"},"mode":"markers+text","name":"","showlegend":false,"text":["Москва","Москва","Москва","Москва","Москва","Москва","Москва","Москва","Славянск-на-Кубани","Ростов-на-Дону","Ростов-на-Дону","Херсон","Симферополь","Симферополь","Нытва","Анапа","Екатеринбург","Екатеринбург","Казань","Ереван","Ярославль","Пермь","Самара","Оренбург","Уфа","Тюмень","Томск","Санкт-Петербург","Санкт-Петербург"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2b3c0e37-506e-471e-b565-0249b65b87ab" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b3c0e37-506e-471e-b565-0249b65b87ab")) {                    Plotly.newPlot(                        "2b3c0e37-506e-471e-b565-0249b65b87ab",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eобратная_цена=%{marker.color}\u003cbr\u003eгород=%{text}\u003cbr\u003eширота=%{lat}\u003cbr\u003eдолгота=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Нижнеудинск","Иркутск","Вологда","Вологда","Вологда","Санкт-Петербург","Череповец","Киров","Верхотурье","Москва","Москва","Москва","Чусовой"],"lat":[54.9,52.28333,59.216667,59.216667,59.216667,59.95,59.11667,58.6,58.86667,55.750556,55.750556,55.750556,58.28333],"legendgroup":"","lon":[99.01667,104.3,39.9,39.9,39.9,30.31667,37.9,49.65,60.8,37.6175,37.6175,37.6175,57.81667],"marker":{"color":[0.004,0.0016666666666666668,0.0013333333333333333,0.0025,0.00125,0.00125,0.0015384615384615385,0.0016666666666666668,0.001176470588235294,0.0022222222222222222,0.0015384615384615385,0.0017241379310344827,0.004],"coloraxis":"coloraxis","opacity":0.8,"size":[0.004,0.0016666666666666668,0.0013333333333333333,0.0025,0.00125,0.00125,0.0015384615384615385,0.0016666666666666668,0.001176470588235294,0.0022222222222222222,0.0015384615384615385,0.0017241379310344827,0.004],"sizemode":"area","sizeref":0.00001,"symbol":"circle"},"mode":"markers+text","name":"","showlegend":false,"text":["Нижнеудинск","Иркутск","Вологда","Вологда","Вологда","Санкт-Петербург","Череповец","Киров","Верхотурье","Москва","Москва","Москва","Чусовой"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a" ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="06afd673-0037-4594-acb5-38e044b8a82b" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("06afd673-0037-4594-acb5-38e044b8a82b")) {                    Plotly.newPlot(                        "06afd673-0037-4594-acb5-38e044b8a82b",                        [{"geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eобратная_цена=%{marker.color}\u003cbr\u003eгород=%{text}\u003cbr\u003eширота=%{lat}\u003cbr\u003eдолгота=%{lon}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Санкт-Петербург","Санкт-Петербург","Москва","Барнаул"],"lat":[59.95,59.95,55.750556,53.347361],"legendgroup":"","lon":[30.31667,30.31667,37.6175,83.77833],"marker":{"color":[0.001176470588235294,0.01,0.0012422360248447205,0.00625],"coloraxis":"coloraxis","opacity":0.8,"size":[0.001176470588235294,0.01,0.0012422360248447205,0.00625],"sizemode":"area","sizeref":0.000025,"symbol":"cross"},"mode":"markers+text","name":"","showlegend":false,"text":["Санкт-Петербург","Санкт-Петербург","Москва","Барнаул"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords", ...

# %% [markdown]
# Тогда выберем по поставщику для каждого растения

# %%
import plotly.express as px
import plotly.graph_objects as go
big_cities=['Екатеринбург','Пермь', 'Ижевск', 'Киров', 'Ростов', 'Ярославль', 'Казань', 'Челябинск', 'Уфа', 'Самара']
data = {
    "город": ["Санкт-Петербург", 'Чусовой', 'Тюмень'],
    "долгота": [30.31667, 57.81667, 65.533330 ],
    "широта": [59.95, 58.283330, 57.150000],
    "растение": ["мелисса", 'иван-чай', 'мята'],
    "цена": [100, 250, 100]
}
df = pd.DataFrame(data)
lonn=[]
latt=[]

for i in big_cities:
  url='https://ru.wikipedia.org/wiki/'+i
  latt.append(get_lat(url))
  lonn.append(get_lon(url))

dtt = {'город': big_cities, 'долгота': lonn, 'широта': latt}
dfbc= pd.DataFrame(dtt)
fig = go.Figure()

print(dfbc)
fig.add_trace(go.Scattergeo(
    lon=df['долгота'],
    lat=df['широта'],
    text=df['город'] + '- ' + df['растение'],
    marker=dict(
        size=10,
        color='green',
        symbol='circle',
        opacity=0.8
    ),
    name='Растения',
    hoverinfo='text'
))


fig.add_trace(go.Scattergeo(
    lon=dfbc['долгота'],
    lat=dfbc['широта'],
    text=dfbc['город'],
    marker=dict(
        size=10,
        color='red',
        symbol='circle',
        opacity=0.8
    ),
    name='Крупные города',
    hoverinfo='text'
))

fig.update_layout(
    title='Города',
    showlegend=True,
    geo=dict(
        projection_type='natural earth',
        showland=True,
        landcolor="rgb(243, 243, 243)",
    ),
    width=1200,
    height=700
)


fig.show()
# Out:
#           город   долгота    широта
# 0  Екатеринбург  60.58333  56.83333
# 1         Пермь  56.24889  58.01389
# 2        Ижевск  53.21222  56.85306
# 3         Киров  49.65000  58.60000
# 4        Ростов  39.41667  57.18333
# 5     Ярославль  39.85000  57.61667
# 6        Казань  49.11444  55.79083
# 7     Челябинск  61.40000  55.15000
# 8           Уфа  55.96667  54.73333
# 9        Самара  50.11667  53.18333
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d4d1ecc0-2bb0-45d1-b077-240fca94bb91" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d4d1ecc0-2bb0-45d1-b077-240fca94bb91")) {                    Plotly.newPlot(                        "d4d1ecc0-2bb0-45d1-b077-240fca94bb91",                        [{"hoverinfo":"text","lat":[59.95,58.28333,57.15],"lon":[30.31667,57.81667,65.53333],"marker":{"color":"green","opacity":0.8,"size":10,"symbol":"circle"},"name":"Растения","text":["Санкт-Петербург- мелисса","Чусовой- иван-чай","Тюмень- мята"],"type":"scattergeo"},{"hoverinfo":"text","lat":[56.83333,58.01389,56.85306,58.6,57.18333,57.61667,55.79083,55.15,54.73333,53.18333],"lon":[60.58333,56.24889,53.21222,49.65,39.41667,39.85,49.11444,61.4,55.96667,50.11667],"marker":{"color":"red","opacity":0.8,"size":10,"symbol":"circle"},"name":"Крупные города","text":["Екатеринбург","Пермь","Ижевск","Киров","Ростов","Ярославль","Казань","Челябинск","Уфа","Самара"],"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar ...

# %%
dictionary={'город': ['Казань'], 'долгота': [49.11444], 'широта': [55.79083], 'растение': ['Сам ты дуб, а я склад'], 'цена': ['не знаю']}
dfd = pd.DataFrame(dictionary)
frames = [dfd, df]

result = pd.concat(frames)
result
# Out:
#              город   долгота    широта               растение     цена
# 0           Казань  49.11444  55.79083  Сам ты дуб, а я склад  не знаю
# 0  Санкт-Петербург  30.31667  59.95000                мелисса      100
# 1          Чусовой  57.81667  58.28333               иван-чай      250
# 2           Тюмень  65.53333  57.15000                   мята      100

# %% [markdown]
# Парсинг для Казани

# %%
import requests
from bs4 import BeautifulSoup

url = "https://kazan.cian.ru/snyat-sklad/"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.text, "html.parser")
t = soup.find_all('li', class_="_32bbee5fda--factoid-item--ABc2c")
gg = soup.find_all('div',class_="_32bbee5fda--userInfo-name--atM0D")
a=[]
print(len(gg))
gg_s=[]
for i in range(1, len(list(t)), 2):
  r = str(t[i]).split('</li>')
  rr= r[0].split('data-name="CommercialFactoid">')
  a.append(rr[1])

for il in range(1, len(list(gg)), 2):
  ry = str(gg[il]).split('</noindex></div>')
  rry= ry[0].split('<noindex>')
  gg_s.append(rry[1])

f=[]
b = a.copy()
for k in range(0, len(b)):
  b[k] = b[k]. split(' руб.')
  f.append(b[k][0])
for y in range(len(f)):
  f[y]=f[y].replace(' ', '')
  f[y]=int(f[y])
dicdic={'арендодатель': gg_s, 'красивое': a[:13], 'численное': f[:13]}

dfgh=pd.DataFrame(dicdic)
dfgh = dfgh.sort_values(by=['численное'])
dfgh
# Out:
# 26
#         арендодатель                 красивое  численное
# 1              Булак     546 руб. за м² в год        546
# 9            DiGROUP   5 600 руб. за м² в год       5600
# 10           DiGROUP   6 400 руб. за м² в год       6400
# 11    Ольга Фомахина   7 200 руб. за м² в год       7200
# 7            DiGROUP   8 400 руб. за м² в год       8400
# 4    Олег Антонченко   9 000 руб. за м² в год       9000
# 2      Инна Смирнова   9 600 руб. за м² в год       9600
# 0         ASG invest   9 600 руб. за м² в год       9600
# 3   АСК Недвижимость  12 000 руб. за м² в год      12000
# 5   GroWealth Estate  14 400 руб. за м² в год      14400
# 8   Мобиус Логистика  15 600 руб. за м² в год      15600
# 6    Олег Антонченко  18 215 руб. за м² в год      18215
# 12           DiGROUP  22 345 руб. за м² в год      22345

# %% [markdown]
# Теперь делаем dashboard

# %%
! pip install --upgrade plotly
! pip install dash-bootstrap-components
# Out:
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (6.0.1)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly) (1.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly) (24.2)
# Collecting dash-bootstrap-components
#   Using cached dash_bootstrap_components-2.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting dash>=3.0.0 (from dash-bootstrap-components)
#   Using cached dash-3.0.0-py3-none-any.whl.metadata (10 kB)
# Collecting Flask<3.1,>=1.0.4 (from dash>=3.0.0->dash-bootstrap-components)
#   Using cached flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting Werkzeug<3.1 (from dash>=3.0.0->dash-bootstrap-components)
#   Using cached werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: plotly>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from dash>=3.0.0->dash-bootstrap-components) (6.0.1)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.11/dist-packages (from dash>=3.0.0->dash-bootstrap-components) (8.6.1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from dash>=3.0.0->dash-bootstrap-components) (4.12.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from dash>=3.0.0->dash-bootstrap-components) (2.32.3)
# Collecting retrying (from dash>=3.0.0->dash-bootstrap-components)
#   Using cached retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.11/dist-packages (from dash>=3.0.0->dash-bootstrap-components) (1.6.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from dash>=3.0.0->dash-bootstrap-components) (75.1.0)
# Collecting stringcase>=1.2.0 (from dash>=3.0.0->dash-bootstrap-components)
#   Using cached stringcase-1.2.0.tar.gz (3.0 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-bootstrap-components) (3.1.6)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-bootstrap-components) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-bootstrap-components) (8.1.8)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.11/dist-packages (from Flask<3.1,>=1.0.4->dash>=3.0.0->dash-bootstrap-components) (1.9.0)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash>=3.0.0->dash-bootstrap-components) (1.31.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from plotly>=5.0.0->dash>=3.0.0->dash-bootstrap-components) (24.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from Werkzeug<3.1->dash>=3.0.0->dash-bootstrap-components) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib-metadata->dash>=3.0.0->dash-bootstrap-components) (3.21.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->dash>=3.0.0->dash-bootstrap-components) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->dash>=3.0.0->dash-bootstrap-components) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->dash>=3.0.0->dash-bootstrap-components) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->dash>=3.0.0->dash-bootstrap-components) (2025.1.31)
# Requirement already satisfied: six>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from retrying->dash>=3.0.0->dash-bootstrap-components) (1.17.0)
# Using cached dash_bootstrap_components-2.0.0-py3-none-any.whl (202 kB)
# Downloading dash-3.0.0-py3-none-any.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 46.4 MB/s eta 0:00:00
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 101.7/101.7 kB 5.1 MB/s eta 0:00:00
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 228.0/228.0 kB 17.0 MB/s eta 0:00:00
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Building wheels for collected packages: stringcase
#   Building wheel for stringcase (setup.py) ... done
#   Created wheel for stringcase: filename=stringcase-1.2.0-py3-none-any.whl size=3568 sha256=7123fbdb1b8dcfb4992c1ddf769e5a2ebd5c5fbeb05f6e2b130092b6407add37
#   Stored in directory: /root/.cache/pip/wheels/b4/33/6d/d0820be98063da218c3206fbad2381cd2db3fbb1a0f0d254b5
# Successfully built stringcase
# Installing collected packages: stringcase, Werkzeug, retrying, Flask, dash, dash-bootstrap-components
#   Attempting uninstall: Werkzeug
#     Found existing installation: Werkzeug 3.1.3
#     Uninstalling Werkzeug-3.1.3:
#       Successfully uninstalled Werkzeug-3.1.3
#   Attempting uninstall: Flask
#     Found existing installation: Flask 3.1.0
#     Uninstalling Flask-3.1.0:
#       Successfully uninstalled Flask-3.1.0
# Successfully installed Flask-3.0.3 Werkzeug-3.0.6 dash-3.0.0 dash-bootstrap-components-2.0.0 retrying-1.3.4 stringcase-1.2.0

# %%
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import plotly.express as px
import pandas as pd


# Инициализация приложения Dash
app = dash.Dash(__name__, external_stylesheets=[dbc.themes.BOOTSTRAP])
'''
# Основные статистики
def calculate_statistics(species_filter):
    filtered_df = df[df['species'] == species_filter] if species_filter else df
    stats = {
        'Количество измерений': len(filtered_df),
        'Средняя длина лепестков': round(filtered_df['petal_length'].mean(), 2),
        'Средняя ширина лепестков': round(filtered_df['petal_width'].mean(), 2)
    }
    return stats
'''
# Графики
def generate_graphs(species_filter):
    filtered_df = result[result['растение'] == species_filter] if species_filter else result

    fig1 = px.scatter_geo(df_mint, lat='широта', lon='долгота', hover_name='Город', title='Мята',
                        color='обратная_цена', size='обратная_цена',
                        projection='equirectangular', symbol_sequence=['star'], color_continuous_scale='RdYlGn', text='Город', width=1200,
                     height=700, opacity=0.8)


    fig2 = px.scatter_geo(df_ivan, lat='широта', lon='долгота', hover_name='город',
                        color='обратная_цена', size='обратная_цена',
                        projection='equirectangular', title='Иван чай', symbol_sequence=['circle'],  color_continuous_scale='RdYlGn', text='город', width=1200,
                     height=700, opacity=0.8)
    fig3 = px.scatter_geo(df_melissa, lat='широта', lon='долгота', hover_name='город',
                        color='обратная_цена', size='обратная_цена',
                        projection='equirectangular', title='Мелисса', symbol_sequence=['cross'],  color_continuous_scale='RdYlGn', text='город', width=1200,
                     height=700, opacity=0.8)

    return fig1, fig2, fig3

# Макет приложения
app.layout = dbc.Container([
    html.H1('Дашборд данных ирисов', className='text-center text-primary mb-4'),

    dbc.Row([
        dbc.Col([
            dbc.Card([
                dbc.CardHeader('Фильтр по растениям'),
                dbc.CardBody([
                    dcc.Dropdown(
                        id='species-dropdown',
                        options=[{'label': species, 'value': species} for species in df['species'].unique()] + [{'label': 'Все виды', 'value': ''}],
                        value='',
                        placeholder='Выберите вид ирисов'
                    )
                ])
            ])
        ], md=4),

        dbc.Col([
            dbc.Card([
                dbc.CardHeader('Основные статистики'),
                dbc.CardBody([
                    html.P(id='measurement-count', className='card-text'),
                    html.P(id='avg-petal-length', className='card-text'),
                    html.P(id='avg-petal-width', className='card-text'),
                ])
            ])
        ], md=8)
    ], className='mb-4'),

    dbc.Row([
        dbc.Col(dcc.Graph(id='scatter-graph'), md=12)
    ]),

    dbc.Row([
        dbc.Col(dcc.Graph(id='hist-petal-length'), md=6),
        dbc.Col(dcc.Graph(id='hist-petal-width'), md=6),
    ]),

], fluid=True)

# Коллбэки для обновления статистики и графиков
@app.callback(
    [Output('measurement-count', 'children'),
     Output('avg-petal-length', 'children'),
     Output('avg-petal-width', 'children'),
     Output('scatter-graph', 'figure'),
     Output('hist-petal-length', 'figure'),
     Output('hist-petal-width', 'figure')],
    [Input('species-dropdown', 'value')]
)
def update_dashboard(species_filter):
    # Обновление статистик
    stats = calculate_statistics(species_filter)
    measurement_count = f"Количество измерений: {stats['Количество измерений']}"
    avg_petal_length = f"Средняя длина лепестков: {stats['Средняя длина лепестков']} см"
    avg_petal_width = f"Средняя ширина лепестков: {stats['Средняя ширина лепестков']} см"

    # Обновление графиков
    fig_scatter, fig_hist_petal_length, fig_hist_petal_width = generate_graphs(species_filter)

    return measurement_count, avg_petal_length, avg_petal_width, fig_scatter, fig_hist_petal_length, fig_hist_petal_width

# Запуск приложения
if __name__ == '__main__':
    app.run(debug=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-8107f6a89b7d> in <cell line: 0>()
# ----> 1 import dash
#       2 from dash import dcc, html
#       3 from dash.dependencies import Input, Output
#       4 import dash_bootstrap_components as dbc
#       5 import plotly.express as px
#
# ModuleNotFoundError: No module named 'dash'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------
